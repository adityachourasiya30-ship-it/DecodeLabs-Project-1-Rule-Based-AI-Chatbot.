# %% [markdown]
# <a href="https://colab.research.google.com/github/adityachourasiya30-ship-it/DecodeLabs-Project-1-Rule-Based-AI-Chatbot./blob/main/Decode_projecct1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Decode lab AI Chatbot")
print("type 'help' to see the availale commands")
print("type by to exit")

while True:
  user =input("you: ").lower().strip()
  if user in ["hi","hello","hey","hae"]:
    print("bot: hello! how can i help you")

  elif user =="how are you":
    print("bot: i am fine, and you")

  elif user =="your name":
    print("bot: i am Decode lab AI Chatbot ,i'm virtual assistant to help you to solve your queries ")

  elif user =="help":
    print("\nAvailable commands:")
    print("hi")
    print("hyy")
    print("hae")
    print("hello")
    print("how are you")
    print("bye")

  elif user in[ "bye","by","byy"]:
    print("bot: bye!! i hope you got your answers.")
    break

  else:
     print("bot: sorry , i don't understand")
# Out:
# Welcome to Decode lab AI Chatbot
# type 'help' to see the availale commands
# type by to exit
